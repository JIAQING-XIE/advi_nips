# %%
import os

import numpy as np
import torch
from pyro.contrib.examples.util import MNIST
import torch.nn as nn
import torchvision.transforms as transforms
from pyro.infer.autoguide.guides import AutoDiagonalNormal

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

# %%
assert pyro.__version__.startswith('1.8.0')
pyro.distributions.enable_validation(False)
pyro.set_rng_seed(0)
# Enable smoke test - run the notebook cells on CI.
smoke_test = 'CI' in os.environ

# %%
def setup_data_loaders(batch_size=128, use_cuda=False):
    root = './data'
    download = True
    trans = transforms.ToTensor()
    train_set = MNIST(root=root, train=True, transform=trans,
                      download=download)
    test_set = MNIST(root=root, train=False, transform=trans)

    kwargs = {'num_workers': 1, 'pin_memory': use_cuda}
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
        batch_size=batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(dataset=test_set,
        batch_size=batch_size, shuffle=False, **kwargs)
    return train_loader, test_loader

# %%
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 784)
        # setup the non-linearities
        self.softplus = nn.Softplus()
        self.sigmoid = nn.Sigmoid()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = self.sigmoid(self.fc21(hidden))
        return loc_img

# %%
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(784, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 784)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale

# %%
def model(self, x):
    # register PyTorch module `decoder` with Pyro
    pyro.module("decoder", self.decoder)
    with pyro.plate("data", x.shape[0]):
        # setup hyperparameters for prior p(z)
        z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
        z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
        # sample from prior (value will be sampled by guide when computing the ELBO)
        z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
        # decode the latent code z
        loc_img = self.decoder(z)
        # score against actual images
        pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

# %%
class VAE(nn.Module):
    # by default our latent space is 50-dimensional
    # and we use 400 hidden units
    def __init__(self, z_dim=50, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
            z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder(z)
            # score against actual images
            pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img

# %%
vae = VAE()
A = AutoDiagonalNormal(vae.model)

# %%
optimizer = Adam({"lr": 1.0e-3})

# %%
svi = SVI(vae.model,A, optimizer, loss=Trace_ELBO())

# %%
def train(svi, train_loader, use_cuda=False):
    # initialize loss accumulator
    epoch_loss = 0.
    # do a training epoch over each mini-batch x returned
    # by the data loader
    for x, _ in train_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(x)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train

# %%
def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for x, _ in test_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(x)
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %%
LEARNING_RATE = 1.0e-3
USE_CUDA = False

# Run only for a single iteration for testing
NUM_EPOCHS = 1 if smoke_test else 100
TEST_FREQUENCY = 5

# %%
train_loader, test_loader = setup_data_loaders(batch_size=256, use_cuda=USE_CUDA)

# clear param store
pyro.clear_param_store()

# setup the VAE
vae = VAE(use_cuda=USE_CUDA)

# setup the optimizer
adam_args = {"lr": LEARNING_RATE}
optimizer = Adam(adam_args)

# setup the inference algorithm
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

train_elbo = []
test_elbo = []
# training loop
for epoch in range(NUM_EPOCHS):
    total_epoch_loss_train = train(svi, train_loader, use_cuda=USE_CUDA)
    train_elbo.append(-total_epoch_loss_train)
    print("[epoch %03d]  average training loss: %.4f" % (epoch, total_epoch_loss_train))

    if epoch % TEST_FREQUENCY == 0:
        # report test diagnostics
        total_epoch_loss_test = evaluate(svi, test_loader, use_cuda=USE_CUDA)
        test_elbo.append(-total_epoch_loss_test)
        print("[epoch %03d] average test loss: %.4f" % (epoch, total_epoch_loss_test))
# Out:
# [epoch 000]  average training loss: 192.5366
# [epoch 000] average test loss: 158.1378
# [epoch 001]  average training loss: 147.3152
# [epoch 002]  average training loss: 133.0903
# [epoch 003]  average training loss: 124.3964
# [epoch 004]  average training loss: 118.8743
# [epoch 005]  average training loss: 115.6740
# [epoch 005] average test loss: 113.6736
# [epoch 006]  average training loss: 113.5664
# [epoch 007]  average training loss: 111.9747
# [epoch 008]  average training loss: 110.7613
# [epoch 009]  average training loss: 109.7644
# [epoch 010]  average training loss: 108.9581
# [epoch 010] average test loss: 107.9596
# [epoch 011]  average training loss: 108.2878
# [epoch 012]  average training loss: 107.8017
# [epoch 013]  average training loss: 107.2884
# [epoch 014]  average training loss: 106.8723
# [epoch 015]  average training loss: 106.5665
# [epoch 015] average test loss: 106.2745
# [epoch 016]  average training loss: 106.2285
# [epoch 017]  average training loss: 105.9925
# [epoch 018]  average training loss: 105.6986
# [epoch 019]  average training loss: 105.4510
# [epoch 020]  average training loss: 105.2544
# [epoch 020] average test loss: 104.8994
# [epoch 021]  average training loss: 105.0975
# [epoch 022]  average training loss: 104.9287
# [epoch 023]  average training loss: 104.7429
# [epoch 024]  average training loss: 104.6594
# [epoch 025]  average training loss: 104.4743
# [epoch 025] average test loss: 104.2798
# [epoch 026]  average training loss: 104.3603
# [epoch 027]  average training loss: 104.2371
# [epoch 028]  average training loss: 104.1497
# [epoch 029]  average training loss: 104.0471
# [epoch 030]  average training loss: 103.9207
# [epoch 030] average test loss: 103.6282
# [epoch 031]  average training loss: 103.8286
# [epoch 032]  average training loss: 103.7381
# [epoch 033]  average training loss: 103.6714
# [epoch 034]  average training loss: 103.5891
# [epoch 035]  average training loss: 103.5409
# [epoch 035] average test loss: 103.6211
# [epoch 036]  average training loss: 103.4569
# [epoch 037]  average training loss: 103.3395
# [epoch 038]  average training loss: 103.2495
# [epoch 039]  average training loss: 103.2531
# [epoch 040]  average training loss: 103.1626
# [epoch 040] average test loss: 102.9429
# [epoch 041]  average training loss: 103.1225
# [epoch 042]  average training loss: 103.0218
# [epoch 043]  average training loss: 102.9691
# [epoch 044]  average training loss: 102.9047
# [epoch 045]  average training loss: 102.8922
# [epoch 045] average test loss: 102.6644
# [epoch 046]  average training loss: 102.8328
# [epoch 047]  average training loss: 102.7606
# [epoch 048]  average training loss: 102.7192
# [epoch 049]  average training loss: 102.6726
# [epoch 050]  average training loss: 102.6268
# [epoch 050] average test loss: 102.7440
# [epoch 051]  average training loss: 102.5757
# [epoch 052]  average training loss: 102.5432
# [epoch 053]  average training loss: 102.5009
# [epoch 054]  average training loss: 102.4393
# [epoch 055]  average training loss: 102.4084
# [epoch 055] average test loss: 102.5173
# [epoch 056]  average training loss: 102.3293
# [epoch 057]  average training loss: 102.3229
# [epoch 058]  average training loss: 102.2662
# [epoch 059]  average training loss: 102.2652
# [epoch 060]  average training loss: 102.2055
# [epoch 060] average test loss: 102.2917
# [epoch 061]  average training loss: 102.1974
# [epoch 062]  average training loss: 102.1021
# [epoch 063]  average training loss: 102.1094
# [epoch 064]  average training loss: 102.0526
# [epoch 065]  average training loss: 102.0486
# [epoch 065] average test loss: 102.2575
# [epoch 066]  average training loss: 101.9807
# [epoch 067]  average training loss: 101.9797
# [epoch 068]  average training loss: 101.9487
# [epoch 069]  average training loss: 101.8775
# [epoch 070]  average training loss: 101.8617
# [epoch 070] average test loss: 102.0532
# [epoch 071]  average training loss: 101.8228
# [epoch 072]  average training loss: 101.7749
# [epoch 073]  average training loss: 101.7542
# [epoch 074]  average training loss: 101.7116
# [epoch 075]  average training loss: 101.6907
# [epoch 075] average test loss: 101.7851
# [epoch 076]  average training loss: 101.6893
# [epoch 077]  average training loss: 101.6349
# [epoch 078]  average training loss: 101.6002
# [epoch 079]  average training loss: 101.6090
# [epoch 080]  average training loss: 101.5372
# [epoch 080] average test loss: 101.7277
# [epoch 081]  average training loss: 101.5260
# [epoch 082]  average training loss: 101.5007
# [epoch 083]  average training loss: 101.4659
# [epoch 084]  average training loss: 101.4284
# [epoch 085]  average training loss: 101.4375
# [epoch 085] average test loss: 101.7197
# [epoch 086]  average training loss: 101.3514
# [epoch 087]  average training loss: 101.3765
# [epoch 088]  average training loss: 101.3350
# [epoch 089]  average training loss: 101.3270
# [epoch 090]  average training loss: 101.2971
# [epoch 090] average test loss: 101.5163
# [epoch 091]  average training loss: 101.2470
# [epoch 092]  average training loss: 101.2334
# [epoch 093]  average training loss: 101.2223
# [epoch 094]  average training loss: 101.1792
# [epoch 095]  average training loss: 101.1714
# [epoch 095] average test loss: 101.5799
# [epoch 096]  average training loss: 101.1344
# [epoch 097]  average training loss: 101.0901
# [epoch 098]  average training loss: 101.0649
# [epoch 099]  average training loss: 101.0328
